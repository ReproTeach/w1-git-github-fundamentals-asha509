# %% [markdown]
# # Week 3 Tuesday In Class Activity

# %%
csv_file = "pre-course_survey.csv"
excel_file = "pre-course_survey.xlsx"

# %%
import pandas as pd

# %%
df_csv = pd.read_csv(csv_file)

# %%
df_csv.shape
# Out:
# (35, 11)

# %%
df_excel = pd.read_excel(excel_file)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File /opt/conda/lib/python3.10/site-packages/pandas/compat/_optional.py:141, in import_optional_dependency(name, extra, errors, min_version)
#     140 try:
# --> 141     module = importlib.import_module(name)
#     142 except ImportError:
#
# File /opt/conda/lib/python3.10/importlib/__init__.py:126, in import_module(name, package)
#     125         level += 1
# --> 126 return _bootstrap._gcd_import(name[level:], package, level)
#
# File <frozen importlib._bootstrap>:1050, in _gcd_import(name, package, level)
#
# File <frozen importlib._bootstrap>:1027, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:1004, in _find_and_load_unlocked(name, import_)
#
# ModuleNotFoundError: No module named 'openpyxl'
#
# During handling of the above exception, another exception occurred:
#
# ...

# %%
# !pip install openpyxl
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 250.0/250.0 kB 7.5 MB/s eta 0:00:00
# ...

# %%
df_excel = pd.read_excel(excel_file)

# %%
df_excel.shape
# Out:
# (35, 11)

# %%
df_csv.columns.values
# Out:
# array(['Timestamp',
#        '1. On a scale of 1 to 5, how would you rate your current knowledge of Python programming?',
#        '2. On a scale of 1 to 5, how would you rate your current knowledge of data science concepts? ',
#        '3. Have you ever used version control systems such as Git and GitHub?',
#        '4. Are you familiar with Jupyter Notebooks or JupyterHub?',
#        '5. On a scale of 1 to 5, how would you rate your understanding of reproducible research principles?',
#        '6. Have you ever conducted text analysis or natural language processing (NLP) projects?',
#        '7. Have you ever worked with social media data or network analysis? ',
#        '8. What are your primary learning goals for this course?',
#        '9. What specific skills or techniques do you hope to gain from this course? ',
#        '10. Do you have any concerns or challenges that you anticipate facing in this course?'],
#       dtype=object)

# %%
old_names = df_csv.columns.values

# %%
new_names = ['timestamp', 'python', 'data_science', 'git', 'jupyter', 'reproducability', 'text_analysis', 'socialmedia', 'learning_goals', 'skills_gain', 'concerns']

# %%
replace_columns = dict(zip(old_names,new_names))

# %%
replace_columns
# Out:
# {'Timestamp': 'timestamp',
#  '1. On a scale of 1 to 5, how would you rate your current knowledge of Python programming?': 'python',
#  '2. On a scale of 1 to 5, how would you rate your current knowledge of data science concepts? ': 'data_science',
#  '3. Have you ever used version control systems such as Git and GitHub?': 'git',
#  '4. Are you familiar with Jupyter Notebooks or JupyterHub?': 'jupyter',
#  '5. On a scale of 1 to 5, how would you rate your understanding of reproducible research principles?': 'reproducability',
#  '6. Have you ever conducted text analysis or natural language processing (NLP) projects?': 'text_analysis',
#  '7. Have you ever worked with social media data or network analysis? ': 'socialmedia',
#  '8. What are your primary learning goals for this course?': 'learning_goals',
#  '9. What specific skills or techniques do you hope to gain from this course? ': 'skills_gain',
# ...

# %%
df_csv.rename(columns=replace_columns, inplace=True)

# %%
df_csv
# Out:
#             timestamp  python  data_science  git jupyter  reproducability  \
# 0   4/1/2023 17:50:33       1             1   No      No                1
# 1   4/1/2023 18:11:14       1             2   No      No                5
# 2   4/1/2023 18:50:40       1             1   No      No                4
# 3   4/1/2023 18:53:09       1             1   No      No                1
# 4   4/1/2023 19:25:36       2             2   No      No                1
# 5   4/1/2023 19:43:48       1             3   No      No                1
# 6   4/1/2023 20:03:11       1             1   No      No                1
# 7   4/1/2023 20:42:55       1             2   No      No                1
# 8   4/1/2023 20:58:16       1             1   No      No                2
# 9   4/1/2023 21:13:10       1             2   No      No                1
# 10  4/1/2023 21:25:53       1             1   No      No                1
# 11   4/2/2023 8:58:39       1             1   No      No                1
# ...

# %%
df_csv.describe()
# Out:
#           python  data_science  reproducability
# count  35.000000     35.000000        35.000000
# mean    1.228571      1.514286         1.542857
# std     0.546955      0.742469         1.038745
# min     1.000000      1.000000         1.000000
# 25%     1.000000      1.000000         1.000000
# 50%     1.000000      1.000000         1.000000
# 75%     1.000000      2.000000         2.000000
# max     3.000000      3.000000         5.000000

# %%
df_csv['python'].value_counts()
# Out:
# 1    29
# 2     4
# 3     2
# Name: python, dtype: int64

# %%
df1_csv = df_csv.replace({'Yes' : 1, 'No' : 0})

# %%
df1_csv
# Out:
#             timestamp  python  data_science  git  jupyter  reproducability  \
# 0   4/1/2023 17:50:33       1             1    0        0                1
# 1   4/1/2023 18:11:14       1             2    0        0                5
# 2   4/1/2023 18:50:40       1             1    0        0                4
# 3   4/1/2023 18:53:09       1             1    0        0                1
# 4   4/1/2023 19:25:36       2             2    0        0                1
# 5   4/1/2023 19:43:48       1             3    0        0                1
# 6   4/1/2023 20:03:11       1             1    0        0                1
# 7   4/1/2023 20:42:55       1             2    0        0                1
# 8   4/1/2023 20:58:16       1             1    0        0                2
# 9   4/1/2023 21:13:10       1             2    0        0                1
# 10  4/1/2023 21:25:53       1             1    0        0                1
# ...

# %%
df1_csv.describe()
# Out:
#           python  data_science        git    jupyter  reproducability  \
# count  35.000000     35.000000  35.000000  35.000000        35.000000
# mean    1.228571      1.514286   0.028571   0.171429         1.542857
# std     0.546955      0.742469   0.169031   0.382385         1.038745
# min     1.000000      1.000000   0.000000   0.000000         1.000000
# 25%     1.000000      1.000000   0.000000   0.000000         1.000000
# 50%     1.000000      1.000000   0.000000   0.000000         1.000000
# 75%     1.000000      2.000000   0.000000   0.000000         2.000000
# max     3.000000      3.000000   1.000000   1.000000         5.000000
#
#        text_analysis  socialmedia
# count      35.000000    35.000000
# mean        0.057143     0.285714
# std         0.235504     0.458349
# min         0.000000     0.000000
# 25%         0.000000     0.000000
# 50%         0.000000     0.000000
# 75%         0.000000     1.000000
# max         1.000000     1.000000

# %%
df1_csv[df1_csv['reproducability'] == 5]
# Out:
#            timestamp  python  data_science  git  jupyter  reproducability  \
# 1  4/1/2023 18:11:14       1             2    0        0                5
#
#    text_analysis  socialmedia                               learning_goals  \
# 1              0            1  To learn more about data science processes.
#
#          skills_gain concerns
# 1  Coding experience       no

# %%
#Exercise answer: goals- To learn more about data science processes. skills- Coding experience concerns- no

# %%
df1_csv.loc[df1_csv['reproducability'] == 5, 'skills_gain']
# Out:
# 1    Coding experience
# Name: skills_gain, dtype: object

# %%
df1_csv.loc[df1_csv['reproducability'] == 5, 'concerns']
# Out:
# 1    no
# Name: concerns, dtype: object

# %%
df1_csv.loc[df1_csv['reproducability'] == 5, 'learning_goals']
# Out:
# 1    To learn more about data science processes.
# Name: learning_goals, dtype: object
